# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Understanding the dataset to explore how the data is present in the database and if there is a need of creating some aggregated tables that can help with
#         * Vendor selection for profitability
#         * Product Pricing Optimizatio

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:<paasword>@localhost:3306/inventorydb')

# %%
df = pd.read_sql("show tables",engine)

# %%
df
# Out:
#   Tables_in_inventorydb
# 0       begin_inventory
# 1         end_inventory
# 2       purchase_prices
# 3             purchases
# 4                 sales
# 5        vendor_invoice

# %%
tables = pd.read_sql("SHOW TABLES", engine)
print(tables)
# Out:
#   Tables_in_inventorydb
# 0       begin_inventory
# 1         end_inventory
# 2       purchase_prices
# 3             purchases
# 4                 sales
# 5        vendor_invoice

# %%
for table in tables['Tables_in_inventorydb']:
    print('-'*25, table, '-'*25)
    print('Count of records:', pd.read_sql(f"select count(*) as count from {table}", engine)['count'].values[0])
    display(pd.read_sql(f"select * from {table} limit 5",engine))
# Out:
# ------------------------- begin_inventory -------------------------
# Count of records: 206529
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# ------------------------- end_inventory -------------------------
# Count of records: 224489
#          InventoryId  Store          City  Brand                  Description  \
# ...

# %%
purchases = pd.read_sql("select * from purchases where VendorNumber = 4466",engine)
purchases
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases_price = pd.read_sql("select * from purchase_prices where VendorNumber = 4466",engine)
purchases_price
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
purchases.groupby(['Brand','PurchasePrice'])[['Quantity','Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
purchases_price
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
invoice = pd.read_sql("select * from vendor_invoice where VendorNumber = 4466",engine)
invoice
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE    2024-02-09      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE    2024-02-17      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE    2024-03-01      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE    2024-03-07      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE    2024-03-12      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE    2024-03-16      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE    2024-03-23      9244
# 12          4466  AMERICAN VINTAGE BEVERAGE    2024-03-31      9371
# ...

# %%
purchases
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
invoice['PONumber'].nunique()
# Out:
# 55

# %%
invoice.shape
# Out:
# (55, 10)

# %%
purchases.columns
# Out:
# <bound method DataFrame.count of               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
inv = invoice.columns

# %%
pp = purchases_price.columns

# %%
df = purchases.columns

# %%
len(df)
# Out:
# 16

# %%
len(pp)
# Out:
# 9

# %%
len(inv)
# Out:
# 10

# %%
sales = pd.read_sql("select * from sales limit 5",engine)
sales
# Out:
#            InventoryId  Store  Brand                 Description        Size  \
# 0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack  375mL 2 Pk
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1         16.49       16.49  2024-01-01   750.0
# 1              2         32.98       16.49  2024-01-02   750.0
# 2              1         16.49       16.49  2024-01-03   750.0
# 3              1         14.49       14.49  2024-01-08   750.0
# 4              2         69.98       34.99  2024-01-09   375.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# ...

# %%
sales.groupby(['Brand'])[['SalesPrice', 'SalesQuantity']].sum()
# Out:
#        SalesPrice  SalesQuantity
# Brand
# 1004        63.96              5
# 1005        34.99              2

# %% [markdown]
# * The purchases table contains actual purchases data, including the date of purchases, products (brands) purchased by vendors, the amount paid (in dollars),
# * The purchases prices column is derived from the purchase_prices table, which provide product-wise actual and purchase prices. The combination of vendor and brand is unique in the table.
# * the vendor_invoice table aggregates data from the purchase table, summarising quantity and dollar amounts, along with an additional column for freight. This table maintains uniqueness based on vendor and PO number.
# * The sales table capture actual sales transactions, detailing and brands purchased by vendors, the quantity sold, the selling price, and the revenue warned.

# %% [markdown]
# As the data that we need for analysis is distributed in diffrent tables, we need to create a summary table containing:
#  * purchase transaction made by vendors.
#  * sales transaction data.
#  * freight costs for each vendor.
#  * actual product prices from vendors.

# %%
freight_summary = pd.read_sql("select VendorNumber, SUM(Freight) as FreightCost from vendor_invoice group by VendorNumber", engine)

# %%
freight_summary
# Out:
#      VendorNumber  FreightCost
# 0             105        62.39
# 1            4466       793.91
# 2             388       211.74
# 3             480     89286.27
# 4             516      8510.41
# ..            ...          ...
# 121        201359         0.09
# 122          4901         0.72
# 123         90059        74.84
# 124          5083        10.68
# 125            54         0.48
#
# [126 rows x 2 columns]

# %%
pd.read_sql("""
SELECT 
    p.VendorNumber,  
    p.VendorName,  
    p.Brand,  
    p.PurchasePrice, 
    pp.Volume,
    pp.Price AS ActualPrice,
    SUM(p.Quantity) AS TotalPurchaseQuantity, 
    SUM(p.Dollars) AS TotalPurchaseDollars 
FROM purchases p 
JOIN purchase_prices pp 
    ON p.Brand = pp.Brand 
    WHERE p.PurchasePrice > 0
GROUP BY 
    p.VendorNumber, 
    p.VendorName, 
    p.Brand,
    p.PurchasePrice,
    pp.Volume,
    pp.Price
ORDER BY 
    TotalPurchaseDollars
""", engine)
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice Volume  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71     50
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47    200
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74     50
# 3              8004  SAZERAC CO INC                5683           0.39     50
# 4              9815  WINE GROUP INC                8527           1.32    750
# ...             ...                          ...    ...            ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89   1750
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17   1750
# 10689         17035  PERNOD RICARD USA             8068          18.24   1750
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19   1750
# 10691          1128  BROWN-FORMAN CORP             1233          26.27   1750
#
# ...

# %%
pd.read_sql("""
SELECT 
    VendorNo,
    Brand,
    SUM(SalesDollars) as TotalSalesDollars,
    SUM(SalesPrice) as TotalSalesPrice,
    SUM(SalesQuantity) as TotalSalesQuantity,
    SUM(ExciseTax) as TotalExciseTax
FROM sales
GROUP BY VendorNo, Brand
ORDER BY TotalSalesDollars
""", engine)
# Out:
#       VendorNo  Brand  TotalSalesDollars  TotalSalesPrice  TotalSalesQuantity  \
# 0         8004   5287               0.98             0.98                 2.0
# 1         9206   2773               0.99             0.99                 1.0
# 2         3252   3933               1.98             0.99                 2.0
# 3        10050   3623               1.98             1.98                 2.0
# 4          660   2134               2.49             2.49                 1.0
# ...        ...    ...                ...              ...                 ...
# 9392      3960   3545         1722112.36        258113.09             54964.0
# 9393      4425   3405         1734093.61        267241.03             57235.0
# 9394     17035   8068         1803317.48        224227.09             72702.0
# 9395      1128   1233         1983632.38        322167.35             54762.0
# 9396      3960   4261         2164653.27        206894.94             96473.0
#
#       TotalExciseTax
# ...

# %%
import time 
start = time.time()
final_table = pd.read_sql("""
SELECT
    pp.VendorNumber,
    pp.VendorName,
    pp.Brand,
    pp.Price as ActualPrice,
    pp.Volume,
    pp.PurchasePrice,
    SUM(s.SalesQuantity) AS TotalSalesQuantity,
    SUM(s.SalesDollars) AS TotalSalesDollars,
    SUM(s.SalesPrice) AS TotalSalesPrice,
    SUM(s.ExciseTax) AS TotalExciseTax,
    SUM(vi.Quantity) AS TotalPurchaseQuantity,
    SUM(vi.Dollars) AS TotalPurchaseDollars,
    SUM(vi.Freight) AS TotalFreightCost
FROM purchase_prices pp
JOIN sales s
     ON pp.VendorNumber = s.VendorNo
     AND pp.Brand = s.Brand
JOIN vendor_invoice vi
     ON pp.VendorNumber = vi.VendorNumber
GROUP BY 
    pp.VendorNumber, 
    pp.Brand, 
    pp.Price, 
    pp.PurchasePrice
""", engine)

end = time.time()

# %%
final_table

# %%
import pandas as pd
import time

start = time.time()

# 1️ purchase_prices 
pp = pd.read_sql("""
SELECT 
    VendorNumber,
    VendorName,
    Brand,
    Price AS ActualPrice,
    Volume,
    PurchasePrice
FROM purchase_prices
""", engine)


# 2️ sales aggregated
sales = pd.read_sql("""
SELECT 
    VendorNo,
    Brand,
    MAX(Description) AS Description,
    SUM(SalesQuantity) AS TotalSalesQuantity,
    SUM(SalesDollars) AS TotalSalesDollars,
    SUM(SalesPrice) AS TotalSalesPrice,
    SUM(ExciseTax) AS TotalExciseTax
FROM sales
GROUP BY VendorNo, Brand
""", engine)


# 3️ vendor_invoice aggregated
vi = pd.read_sql("""
SELECT 
    VendorNumber,
    SUM(Quantity) AS TotalPurchaseQuantity,
    SUM(Dollars) AS TotalPurchaseDollars,
    SUM(Freight) AS TotalFreightCost
FROM vendor_invoice
GROUP BY VendorNumber
""", engine)


#  Merge 1: purchase_prices + sales
df = pd.merge(
    pp,
    sales,
    left_on=["VendorNumber", "Brand"],
    right_on=["VendorNo", "Brand"],
    how="left"
)

# drop duplicate column
df.drop(columns=["VendorNo"], inplace=True)


#  Merge 2: above + vendor_invoice
final_table = pd.merge(
    df,
    vi,
    on="VendorNumber",
    how="left"
)


end = time.time()

print("Time taken:", end - start)

# Preview
print(final_table.head())
# Out:
# Time taken: 56.958336353302
#    VendorNumber                   VendorName  Brand  ActualPrice Volume  \
# 0          8320  SHAW ROSS INT L IMP LTD         58        12.99    750
# 1          1128  BROWN-FORMAN CORP               62        36.99    750
# 2          1128  BROWN-FORMAN CORP               63        38.99    750
# 3          9165  ULTRA BEVERAGE COMPANY LLP      72        34.99    750
# 4          7245  PROXIMO SPIRITS INC.            75        14.99    750
#
#    PurchasePrice                  Description  TotalSalesQuantity  \
# 0           9.28  Gekkeikan Black & Gold Sake              1589.0
# 1          28.67     Herradura Silver Tequila              1481.0
# 2          30.46   Herradura Reposado Tequila              1265.0
# 3          26.11         No. 3 London Dry Gin               252.0
# 4          10.94    Three Olives Tomato Vodka                19.0
#
#    TotalSalesDollars  TotalSalesPrice  TotalExciseTax  TotalPurchaseQuantity  \
# ...

# %%
final_table
# Out:
#        VendorNumber                   VendorName  Brand  ActualPrice Volume  \
# 0              8320  SHAW ROSS INT L IMP LTD         58        12.99    750
# 1              1128  BROWN-FORMAN CORP               62        36.99    750
# 2              1128  BROWN-FORMAN CORP               63        38.99    750
# 3              9165  ULTRA BEVERAGE COMPANY LLP      72        34.99    750
# 4              7245  PROXIMO SPIRITS INC.            75        14.99    750
# ...             ...                          ...    ...          ...    ...
# 12256         90024  VINILANDIA USA               44917        24.99    750
# 12257          4425        MARTIGNETTI COMPANIES  44944        22.99    750
# 12258         10754  PERFECTA WINES               45016        93.99    750
# 12259          9744  FREDERICK WILDMAN & SONS     46011        12.99   1500
# 12260         10754  PERFECTA WINES               46964        35.99    750
#
# ...

# %% [markdown]
# This Query generates a vendor-wise sales and purchases summary, which is valuable for:
# Performance Optimization:
# * The Query involves heavy joins and aggregations on large datasets like sales purchses.
# * Storing the pre-aggregated results avoids repeated expensive computations.
# * Helps in analyzing sales, purchases, and pricing for different vendors and brands.
# * Furure Benefits of Storing this data for faster Dashborading & Reporting.
# * Instead of running expensive quesries each time, dashboads can fetch data quickly from vendor_sales_summary

# %%
final_table.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# ActualPrice              float64
# Volume                   float64
# PurchasePrice            float64
# Description               object
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# TotalPurchaseQuantity    float64
# TotalPurchaseDollars     float64
# TotalFreightCost         float64
# dtype: object

# %%
final_table.isnull().sum()
# Out:
# VendorNumber             0
# VendorName               0
# Brand                    0
# ActualPrice              0
# Volume                   0
# PurchasePrice            0
# Description              0
# TotalSalesQuantity       0
# TotalSalesDollars        0
# TotalSalesPrice          0
# TotalExciseTax           0
# TotalPurchaseQuantity    0
# TotalPurchaseDollars     0
# TotalFreightCost         0
# dtype: int64

# %%
final_table['VendorName'].unique()
# Out:
# array(['SHAW ROSS INT L IMP LTD', 'BROWN-FORMAN CORP',
#        'ULTRA BEVERAGE COMPANY LLP', 'PROXIMO SPIRITS INC.',
#        'MOET HENNESSY USA INC', 'BACARDI USA INC',
#        'JIM BEAM BRANDS COMPANY', 'CAMPARI AMERICA',
#        'WILLIAM GRANT & SONS INC', 'MARTIGNETTI COMPANIES',
#        'CONSTELLATION BRANDS INC', 'M S WALKER INC',
#        'DIAGEO NORTH AMERICA INC', 'MCCORMICK DISTILLING CO',
#        'PERNOD RICARD USA', 'PINE STATE TRADING CO',
#        'STATE WINE & SPIRITS', 'DISARONNO INTERNATIONAL LLC',
#        'SAZERAC CO INC', 'PERFECTA WINES', 'HEAVEN HILL DISTILLERIES',
#        'LABELLE VYDS AND WINERY', 'REMY COINTREAU USA INC',
#        'SIDNEY FRANK IMPORTING CO', 'MHW LTD', 'PHILLIPS PRODUCTS CO.',
#        'LUXCO INC', 'WESTERN SPIRITS BEVERAGE CO', 'CASTLE BRANDS CORP.',
#        'SAZERAC NORTH AMERICA INC.', 'OLE SMOKY DISTILLERY LLC',
#        'STOLI GROUP,(USA) LLC', 'SMOKY QUARTZ DISTILLERY LLC',
#        'VINEDREA WINES LLC', 'EDRINGTON AMERICAS',
# ...

# %%
final_table['Description'].unique()
# Out:
# array(['Gekkeikan Black & Gold Sake', 'Herradura Silver Tequila',
#        'Herradura Reposado Tequila', ..., 'Frank Family Vyds Cab Svgn',
#        'Feast Agiorgitiko', 'Feast Moschofilero'],
#       shape=(8636,), dtype=object)

# %%
final_table['Volume'] = pd.to_numeric(
    final_table['Volume']
        .astype(str)
        .str.replace('[^0-9.]', '', regex=True),
    errors='coerce'
)

# %%
final_table.fillna(0, inplace = True)

# %%
final_table['VendorName'] = final_table['VendorName'].str.strip()

# %%
final_table
# Out:
#        VendorNumber                  VendorName  Brand  ActualPrice  Volume  \
# 0              8320     SHAW ROSS INT L IMP LTD     58        12.99   750.0
# 1              1128           BROWN-FORMAN CORP     62        36.99   750.0
# 2              1128           BROWN-FORMAN CORP     63        38.99   750.0
# 3              9165  ULTRA BEVERAGE COMPANY LLP     72        34.99   750.0
# 4              7245        PROXIMO SPIRITS INC.     75        14.99   750.0
# ...             ...                         ...    ...          ...     ...
# 12256         90024              VINILANDIA USA  44917        24.99   750.0
# 12257          4425       MARTIGNETTI COMPANIES  44944        22.99   750.0
# 12258         10754              PERFECTA WINES  45016        93.99   750.0
# 12259          9744    FREDERICK WILDMAN & SONS  46011        12.99  1500.0
# 12260         10754              PERFECTA WINES  46964        35.99   750.0
#
# ...

# %%
final_table['GrossProfit'] = final_table['TotalSalesDollars'] - final_table['TotalPurchaseDollars']

# %%
final_table['GrossProfit'].min()
# Out:
# np.float64(-50959796.849999994)

# %%
final_table['GrossProfit']
# Out:
# 0         -604338.53
# 1       -13472200.89
# 2       -13478050.73
# 3       -13201336.45
# 4        -7587745.09
#             ...
# 12256     -548855.37
# 12257   -27861690.02
# 12258    -5665501.53
# 12259     -759449.24
# 12260    -5665501.53
# Name: GrossProfit, Length: 12261, dtype: float64

# %%
final_table['ProfitMargin'] = (final_table['GrossProfit'] / final_table['TotalSalesDollars'])*100

# %%
final_table['ProfitMargin']
# Out:
# 0       -2.927839e+03
# 1       -2.353955e+04
# 2       -2.623090e+04
# 3       -1.422944e+05
# 4       -2.664143e+06
#              ...
# 12256            -inf
# 12257            -inf
# 12258            -inf
# 12259            -inf
# 12260            -inf
# Name: ProfitMargin, Length: 12261, dtype: float64

# %%
final_table['StockTurnover'] =  final_table['TotalSalesQuantity'] /   final_table['TotalPurchaseQuantity']

# %%
final_table['StockTurnover']
# Out:
# 0        0.022987
# 1        0.001472
# 2        0.001257
# 3        0.000234
# 4        0.000028
#            ...
# 12256    0.000000
# 12257    0.000000
# 12258    0.000000
# 12259    0.000000
# 12260    0.000000
# Name: StockTurnover, Length: 12261, dtype: float64

# %%
final_table['SalesToPucharseRatio'] = final_table['TotalSalesDollars'] / final_table['TotalPurchaseDollars']

# %%
final_table['SalesToPucharseRatio']
# Out:
# 0        0.033027
# 1        0.004230
# 2        0.003798
# 3        0.000702
# 4        0.000038
#            ...
# 12256    0.000000
# 12257    0.000000
# 12258    0.000000
# 12259    0.000000
# 12260    0.000000
# Name: SalesToPucharseRatio, Length: 12261, dtype: float64

# %%
conn = engine.raw_connection()
cursor = conn.cursor()

# %%
final_table.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'ActualPrice', 'Volume',
#        'PurchasePrice', 'Description', 'TotalSalesQuantity',
#        'TotalSalesDollars', 'TotalSalesPrice', 'TotalExciseTax',
#        'TotalPurchaseQuantity', 'TotalPurchaseDollars', 'TotalFreightCost',
#        'GrossProfit', 'ProfitMargin', 'StockTurnover', 'SalesToPucharseRatio'],
#       dtype='object')

# %%
cursor.execute("""CREATE TABLE vendor_sales_summary (
    VendorNumber INT,
    VendorName VARCHAR(100),
    Brand INT,
    ActualPrice DECIMAL(10, 2),
    Volume FLOAT,
    PurchasePrice DECIMAL(10,2),
    Description VARCHAR(100),
    TotalSalesQuantity INT,
    TotalSalesDollars DECIMAL(15,2),
    TotalSalesPrice DECIMAL(15,2),
    TotalExciseTax DECIMAL(15,2),
    TotalPurchaseQuantity INT,
    TotalPurchaseDollars DECIMAL(15,2),
    TotalFreightCost DECIMAL(15,2),
    GrossProfit DECIMAL(15,2),
    ProfitMargin DECIMAL(15,2),
    StockTurnover DECIMAL(15,2),
    SalesToPucharseRatio DECIMAL(15,2),
    PRIMARY KEY (VendorNumber, Brand)
);

""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 cursor.execute("""CREATE TABLE vendor_sales_summary (
#       2     VendorNumber INT,
#       3     VendorName VARCHAR(100),
#       4     Brand INT,
#       5     ActualPrice DECIMAL(10, 2),
#       6     Volume FLOAT,
#       7     PurchasePrice DECIMAL(10,2),
#       8     Description VARCHAR(100),
#       9     TotalSalesQuantity INT,
#      10     TotalSalesDollars DECIMAL(15,2),
#      11     TotalSalesPrice DECIMAL(15,2),
#      12     TotalExciseTax DECIMAL(15,2),
#      13     TotalPurchaseQuantity INT,
#      14     TotalPurchaseDollars DECIMAL(15,2),
#      15     TotalFreightCost DECIMAL(15,2),
#      16     GrossProfit DECIMAL(15,2),
#      17     ProfitMargin DECIMAL(15,2),
#      18     StockTurnover DECIMAL(15,2),
#      19     SalesToPucharseRatio DECIMAL(15,2),
# ...

# %%
pd.read_sql("Select * from vendor_sales_summary", engine)
# Out:
# Empty DataFrame
# Columns: [VendorNumber, VendorName, Brand, ActualPrice, Volume, PurchasePrice, Description, TotalSalesQuantity, TotalSalesDollars, TotalSalesPrice, TotalExciseTax, TotalPurchaseQuantity, TotalPurchaseDollars, TotalFreightCost, GrossProfit, ProfitMargin, StockTurnover, SalesToPucharseRatio]
# Index: []

# %%
final_table.to_sql(
    "vendor_sales_summary",
    con=engine,
    if_exists='append',   
    index=False,
    chunksize=1000     
)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:196, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     189 def do_executemany(
#     190     self,
#     191     cursor: DBAPICursor,
#    (...)
#     194     context: Optional[ExecutionContext] = None,
# ...

# %%
import numpy as np

final_table.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
final_table = final_table.where(pd.notnull(final_table), None)

# %%
final_table.fillna(0, inplace=True)

# %%
final_table.to_sql(
    "vendor_sales_summary",
    con=engine,
    if_exists='append',
    index=False,
    chunksize=1000
)
# Out:
# 12261

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 vendor_sales_summary
#
# NameError: name 'vendor_sales_summary' is not defined
